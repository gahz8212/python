# %% [markdown]
# <a href="https://colab.research.google.com/github/gahz8212/python/blob/master/%EB%84%A4%EC%9D%B4%EB%B2%84api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
import urllib.request
import json #파이썬에서는 key로 값을 추출하기 위해 dict로 변경해 줘야 한다.
import pandas as pd
import numpy as np

client_id = "_vYOQl5SVtfGtW3MvoHI"
client_secret = "HhnQ5Y2Js4"
encText = urllib.parse.quote("가산동 맛집")#utf-8로 인코딩된 텍스트
total_list=[]
for i in range(1,1001,100):
  display=str(100)
  start=str(i)
  url = "https://openapi.naver.com/v1/search/blog?query=" + encText+"&display="+display+"&start="+start # JSON 결과
  # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과

  #http헤더 만드는 부분
  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)

  response = urllib.request.urlopen(request)#네이버 서버에 http요청
  #http응답이 response변수로 쏙 들어감.

  #http에는 header + body가 있음.
  #응답용 http의 header에는 code + message + http버전(v1.1)
  #응답용 http의 body에는 전달데이터(json)가 들어있음
  rescode = response.getcode()#header에는 code추출(200)
  if(rescode==200):
      response_body= response.read()#body에는 전달데이터(json)추출
      #print(response_body.decode('utf-8'))
      json_data=json.loads(response_body.decode('utf-8'))


  else:
      print("Error Code:" + rescode)

  items=json_data['items']






  for one in items:
      link=one['link']
      title=one['title']
      description=one['description']
      bloggername=one['bloggername']
      bloggerlink=one['bloggerlink']
      postdate=one['postdate']
      data=[title,link,description,bloggername,bloggerlink,postdate]
      total_list.append(data)


#df=pd.DataFrame(data=getDatas(),columns=['title','link','description','bloogername','bloggerlink','postdate'])
#df.to_csv('가산동 맛집.csv',index=False)
#df
# Out:
# 10

# %%
one=json_data['items'][0]
link=one['link']
title=one['title']
description=one['description']
bloggername=one['bloggername']
bloggerlink=one['bloggerlink']
postdate=one['postdate']



def getDatas():
  datas=[]

  for page in range(10):


      link=one['link']
      title=one['title']
      description=one['description']
      bloggername=one['bloggername']
      bloggerlink=one['bloggerlink']
      postdate=one['postdate']
      data=[title,link,description,bloggername,bloggerlink,postdate]
      datas.append(data)
  return datas
print(len(getDatas()))
#df=pd.DataFrame(data=getDatas(),columns=['title','link','description','bloogername','bloggerlink','postdate'])
#df.to_csv('가산동 맛집.csv',index=False)
#df
# Out:
# 10

# %%
for i in range(1,1000,100):
  print(i)
# Out:
# 1
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901
